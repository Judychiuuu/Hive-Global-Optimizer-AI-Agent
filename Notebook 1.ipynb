# %%
import ast
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
from dateutil.relativedelta import relativedelta
from pyspark.sql.functions import col
# Out:
# StatementMeta(, f2f18d6c-122d-4879-ae7d-45fd2e40c486, 3, Finished, Available, Finished, False)

# %%
# Welcome to your new notebook
# Type here in the cell editor to add code!
old_run_id_to_copy = '21d445b4-c6a4-4ca7-b850-05124c6d8219'
name = 'JudyTestingRun'
description = 'This run is for testign only'
user = 'judy.chiu@hivefs.com'
objective_function = 'Maximize Bank Balance'
duration = 1351
overhead_per_period = 0 #Overhead set by period
mip_gap = 0.001
timeout_seconds = 600
start_period = 461
# Out:
# StatementMeta(, f2f18d6c-122d-4879-ae7d-45fd2e40c486, 4, Finished, Available, Finished, False)

# %%
result = mssparkutils.notebook.run("DE_NB_CopyRun", timeout_seconds, {
    "old_run_id": old_run_id_to_copy,
    "name": name,
    "description": description,
    "duration": duration,
    "user": user
})

new_run_id = ast.literal_eval(result)['new_run_id']
new_run_id
# Out:
# StatementMeta(, f2f18d6c-122d-4879-ae7d-45fd2e40c486, 5, Finished, Available, Finished, False)
# 'dbc14f6d-b0f3-4556-b7e5-2e63b4037edc'

# %%
new_run_id = 'dbc14f6d-b0f3-4556-b7e5-2e63b4037edc'
# Out:
# StatementMeta(, f2f18d6c-122d-4879-ae7d-45fd2e40c486, 6, Finished, Available, Finished, False)

# %% [markdown]
# Do changes based on input JSON schema on new_run_id rows in all input tables.
# Leave all other run_id rows untouched.
